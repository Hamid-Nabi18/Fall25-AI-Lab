# %%
previous_number = 0

for current_number in range(1, 21):
    print(f"Computer picks: {current_number}")
    total = previous_number + current_number
    print(f"Total so far: {previous_number} + {current_number} = {total}")

    if total % 3 == 0 and total % 5 == 0:
        print("Computer says: FizzBuzz!")
    elif total % 3 == 0:
        print("Computer says: Fizz!")
    elif total % 5 == 0:
        print("Computer says: Buzz!")
    else:
        print(f"Computer says: {total}")

    print()
    previous_number = current_number
# Out:
# Computer picks: 1
# Total so far: 0 + 1 = 1
# Computer says: 1
#
# Computer picks: 2
# Total so far: 1 + 2 = 3
# Computer says: Fizz!
#
# Computer picks: 3
# Total so far: 2 + 3 = 5
# Computer says: Buzz!
#
# Computer picks: 4
# Total so far: 3 + 4 = 7
# Computer says: 7
#
# Computer picks: 5
# Total so far: 4 + 5 = 9
# Computer says: Fizz!
#
# Computer picks: 6
# Total so far: 5 + 6 = 11
# Computer says: 11
#
# Computer picks: 7
# Total so far: 6 + 7 = 13
# Computer says: 13
#
# Computer picks: 8
# Total so far: 7 + 8 = 15
# Computer says: FizzBuzz!
#
# Computer picks: 9
# Total so far: 8 + 9 = 17
# Computer says: 17
#
# Computer picks: 10
# Total so far: 9 + 10 = 19
# Computer says: 19
#
# Computer picks: 11
# Total so far: 10 + 11 = 21
# Computer says: Fizz!
#
# Computer picks: 12
# Total so far: 11 + 12 = 23
# Computer says: 23
#
# Computer picks: 13
# Total so far: 12 + 13 = 25
# Computer says: Buzz!
#
# Computer picks: 14
# Total so far: 13 + 14 = 27
# Computer says: Fizz!
#
# Computer picks: 15
# Total so far: 14 + 15 = 29
# Computer says: 29
#
# Computer picks: 16
# Total so far: 15 + 16 = 31
# Computer says: 31
#
# Computer picks: 17
# Total so far: 16 + 17 = 33
# Computer says: Fizz!
#
# Computer picks: 18
# Total so far: 17 + 18 = 35
# Computer says: Buzz!
#
# Computer picks: 19
# Total so far: 18 + 19 = 37
# Computer says: 37
#
# Computer picks: 20
# Total so far: 19 + 20 = 39
# Computer says: Fizz!
